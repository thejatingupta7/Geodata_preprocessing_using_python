# %% [markdown]
# # Vector Data Processing

# %% [markdown]
# # Geoprocessing

# %% [markdown]
# Vector data represent objects on the Earth's surface using their longitude and latitude, as well as combinations of the pairs of coordinates (lines, polylines, polygons, etc.).
# ### Point data
#
# A pair of coordinates (longitude, latitude), that represents the location of points on the Earth's surface
#
# Example: Location of drop boxes, landmarks, etc.<br><br>
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Lines
#
# A series of points that represents a line (straight or otherwise) on the Earth's surface.
#
# Example: Center of roads, rivers, etc.<br><br>
# ![image.png](attachment:image.png)

# %% [markdown]
#  ## Polygons
#  A series of points (vertices) that define the outer edge of a region.
#
# Example: Outlines of cities and continents, etc.<br><br>
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Introduction to Pandas

# %% [markdown]
# ## Learning Objectives:
#
# 1. Gain an introduction to the DataFrame and Series data structures of the pandas library
# 2. Access and manipulate data within a DataFrame and Series
# 3. Import CSV data into a pandas DataFrame
#
# Pandas is an open source, BSD-licensed library providing high-performance, easy-to-use data structures and data analysis tools for
# the Python programming language.
#
# Pandas is a column-oriented data analysis python library. It's a great tool for handling and analyzing input data.

# %% [markdown]
# ## Pandas Basics

# %% [markdown]
# The primary data structures in pandas are implemented as two classes:
# 1. DataFrame, which you can imagine as a relational data table, with rows and named columns.
# 2. Series, which is a single column. A DataFrame contains one or more Series and a name for each Series.
#
# The data frame is a commonly used abstraction for data manipulation.

# %% [markdown]
# # Introduction to Geo Pandas

# %% [markdown]
# GeoPandas is an open source project to make working with geospatial data in python easier. GeoPandas extends the datatypes used by pandas to allow spatial operations on geometric types.
#
# The primary data structures in geopandas are implemented as two classes:
# 1. <b>GeoSeries</b>, is essentially a vector where each entry in the vector is a set of shapes corresponding to one observation. <br>
# Geopandas* has three basic classes of geometric objects:<br>
# (i)   Points / Multi-Points<br>
# (ii)  c Lines / Multi-Lines<br>
# (iii) Polygons / Multi-Polygons<br><br>
# 2. <b>GeoDataFrame</b>, is a tabular data structure that contains a GeoSeries.The most important property of a GeoDataFrame is that it always has one GeoSeries column that holds a special status. This GeoSeries is referred to as the GeoDataFrame's "geometry".

# %% [markdown]
# ## Reading and Writing Spatial Data

# %% [markdown]
# ### Vector Data Formats

# %% [markdown]
# <b>ESRI Sahpe File</b> is simple, nontopological format for storing the geometric location and attribute
# information of geographic features. The shapefile format defines the geometry and attributes of
# geographically referenced features in three or more files with specific file extensions:
# 1. .shp-The main file that stores the feature geometry; required.
# 2. .shx-The index file that stores the index of the feature geometry; required.
# 3. .dbf-The dBASE table that stores the attribute information of features; required.
# 4. .sbn and .sbx-The files that store the spatial index of the features.
# 5. .prj-The file that stores the coordinate system information

# %% [markdown]
# <b>GeoJSON</b> is a format for encoding a variety of geographic data structures.A GeoJSON object may
# represent a region of space (a Geometry), a spatially bounded entity (a Feature), or a list of Features (a
# FeatureCollection). GeoJSON supports the following geometry types: Point, LineString, Polygon, MultiPoint,
# MultiLineString, MultiPolygon, and GeometryCollection. Features in GeoJSON contain a Geometry object
# and additional properties, and a FeatureCollection contains a list of Features.

# %% [markdown]
# <b>Other formats:</b>
# 1. Geography Markup Language
# 2. keyhole Markup Language
# 3. MongoDB
# 4. Microsoft SQL Server Database
# 5. OGC WFS service
# 6. etc.

# %% [markdown]
# ### Importing Vector Data (.shp)

# %%
import geopandas as gpd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from geopandas import GeoSeries

# %%
vector_file = "vector_maps/map.shp"

# %%
india = gpd.read_file(vector_file)

# %%
type(india)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
india.geometry.name
# Out:
# 'geometry'

# %%
india.crs

# %% [markdown]
#  Coordinate Reference System (CRS) of the spatial data. The CRS defines how the spatial coordinates of geometries are related to real-world locations.

# %% [markdown]
# ### Renaming a Column

# %%
india = india.rename(columns={"geometry": "borders"}).set_geometry("borders")

# %%
india.head()
# Out:
#    ID_0  ISO NAME_0  ID_1               NAME_1  \
# 0   105  IND  India  1287  Andaman and Nicobar
# 1   105  IND  India  1288       Andhra Pradesh
# 2   105  IND  India  1289    Arunachal Pradesh
# 3   105  IND  India  1290                Assam
# 4   105  IND  India  1291                Bihar
#
#                                            VARNAME_1 NL_NAME_1 HASC_1  CC_1  \
# 0  Andaman & Nicobar Islands|Andaman et Nicobar|I...      None  IN.AN  None
# 1                                               None      None  IN.AP  None
# 2  Agence de la Frontisre du Nord-Est(French-obso...      None  IN.AR  None
# 3                                               None      None  IN.AS  None
# 4                                               None      None  IN.BR  None
#
#            TYPE_1        ENGTYPE_1 VALIDFR_1 VALIDTO_1 REMARKS_1  Shape_Leng  \
# 0  Union Territor  Union Territory      None      None      None   33.514047
# ...

# %%
india.plot(figsize=(18,14))
# ladakh and POK is indian territory! No other map available!
# Out:
# <Axes: >

# %% [markdown]
# ### Reading Shape File (.zip)

# %%
vector_file = r"vector_data/StatPlanet_India.zip!StatPlanet_India_Hindi/map/map.shp"

# %%
india = gpd.read_file(vector_file)

# %%
india.head()
# Out:
#    ID_0  ISO NAME_0  ID_1               NAME_1  \
# 0   105  IND  India  1287  Andaman and Nicobar
# 1   105  IND  India  1288       Andhra Pradesh
# 2   105  IND  India  1289    Arunachal Pradesh
# 3   105  IND  India  1290                Assam
# 4   105  IND  India  1291                Bihar
#
#                                            VARNAME_1 NL_NAME_1 HASC_1  CC_1  \
# 0  Andaman & Nicobar Islands|Andaman et Nicobar|I...      None  IN.AN  None
# 1                                               None      None  IN.AP  None
# 2  Agence de la Frontisre du Nord-Est(French-obso...      None  IN.AR  None
# 3                                               None      None  IN.AS  None
# 4                                               None      None  IN.BR  None
#
#            TYPE_1        ENGTYPE_1 VALIDFR_1 VALIDTO_1 REMARKS_1  Shape_Leng  \
# 0  Union Territor  Union Territory      None      None      None   33.514047
# ...

# %%
india.plot(figsize=(18,14))
# Out:
# <Axes: >

# %%
plt.close()

# %% [markdown]
# ### Subsetting <i>GeoDataFrame</i> File

# %%
subset = india[india["NAME_1"] == "Uttar Pradesh"]

# %%
subset.plot()
# Out:
# <Axes: >

# %%
# %pip install branca

# %%
# %pip install folium

# %%
# %pip install mapclassify

# %%
subset.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
plt.close()

# %% [markdown]
# #### Writing Shape File

# %%
subset.to_file("vector_data/uttarpradesh.shp")

# %% [markdown]
# ### Reading <i>GeoJSON</i> File (.geojson)

# %%
gson = "vector_data/india_states.geojson"

# %%
df = gpd.read_file(gson)

# %%
df.head()
# Out:
#    ID_0  ISO NAME_0  ID_1               NAME_1 NL_NAME_1  \
# 0   105  IND  India     1  Andaman and Nicobar
# 1   105  IND  India     2       Andhra Pradesh
# 2   105  IND  India     3    Arunachal Pradesh
# 3   105  IND  India     4                Assam
# 4   105  IND  India     5                Bihar
#
#                                            VARNAME_1          TYPE_1  \
# 0  Andaman & Nicobar Islands|Andaman et Nicobar|I...  Union Territor
# 1                                                              State
# 2  Agence de la Frontire du Nord-Est(French-obsol...           State
# 3                                                              State
# 4                                                              State
#
#          ENGTYPE_1 filename filename_1 filename_2 filename_3 filename_4  \
# 0  Union Territory
# 1            State
# 2            State
# 3            State
# 4            State
#
#                                             geometry
# ...

# %%
df.plot()
# Out:
# <Axes: >

# %%
goa = df[df["NAME_1"] == "Goa"]

# %%
goa.plot()
# Out:
# <Axes: >

# %%
goa.to_file("vector_data/goa.shp")

# %% [markdown]
# ### Managing Projections

# %% [markdown]
# <b>Coordinate Reference Systems (CRS): </b> A Coordinate Reference System (CRS) describes how the
# coordinates in a geospatial dataset relate to locations on the surface of the earth.
#
# <b>A geographic CRS consists of: </b><br>
# A 3D model of the shape of the earth (a datum), approximated as a sphere or spheroid (e.g., an ellipsoid),
# The units of the coordinate system (e.g, decimal degrees, meters, feet), and The origin (i.e., the 0,0 location),
# specified as the meeting of the equator and the prime meridian.

# %% [markdown]
# <b>A projected CRS consists of:</b><br>
# A geographic CRS, and A map projection and related parameters used to transform the geographic
# coordinates to 2D space. A map projection is a mathematical model used to transform coordinate data
#
# CRS are important because the geometric shapes in a GeoSeries or GeoDataFrame object are simply a
# collection of coordinates in an arbitrary space. A CRS tells Python how those coordinates related to places
# on the Earth.
#
# <i>Geopandas</i> can accept lots of representations of CRS
#
# 1. Proj4 String: "+proj=longlat +ellps=WGS84 +datum=WGS84 +no_defs"
# 2. parameters broken out in a dictionary: {'p:oj': 'latlong', 'ellps': 'WGS84, 'datum': 'WGS84'))
# 3. EPSG codes directly

# %% [markdown]
# ### Identifying the CRS of a GeoDataFrame

# %%
vector_file = r"vector_data/india_states.geojson"
india = gpd.read_file(vector_file)

# %%
india.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# #### Setting a Projection

# %% [markdown]
# Setting a projection is how one tells geopandas how to interpret coordinates. CRS can be set by setting
# <br><b>.crs={'init' :'epsg:4326'}</b>

# %%
india.crs = None

# %%
india.crs

# %% [markdown]
# #### Reprojecting

# %% [markdown]
# Re-projecting is the process of changing the representation of locations from one coordinate system to another data can be re-projected using the <b>to_crs</b> command.

# %%
india = gpd.read_file(vector_file)

# %%
india.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
india_rep = india.to_crs(epsg=3857)

# %%
india.plot()
plt.title("LCC WGS84 (lat/lon)")
# Out:
# Text(0.5, 1.0, 'LCC WGS84 (lat/lon)')

# %%
india_rep.plot()
plt.title("Mercator")
# Out:
# Text(0.5, 1.0, 'Mercator')

# %% [markdown]
# ### Mapping with GeoPandas

# %%
vector_file = r"vector_data/StatPlanet_India.zip!StatPlanet_India_Hindi/map/map.shp"

# %% [markdown]
# <i>GeoPandas</i> provides a high-level interface to the matplotlib library for making maps. Mapping shapes is as easy as using the plot() method on a GeoSeries or GeoDataFrame.

# %%
india = gpd.read_file(vector_file)

# %%
india.head()
# Out:
#    ID_0  ISO NAME_0  ID_1               NAME_1  \
# 0   105  IND  India  1287  Andaman and Nicobar
# 1   105  IND  India  1288       Andhra Pradesh
# 2   105  IND  India  1289    Arunachal Pradesh
# 3   105  IND  India  1290                Assam
# 4   105  IND  India  1291                Bihar
#
#                                            VARNAME_1 NL_NAME_1 HASC_1  CC_1  \
# 0  Andaman & Nicobar Islands|Andaman et Nicobar|I...      None  IN.AN  None
# 1                                               None      None  IN.AP  None
# 2  Agence de la Frontisre du Nord-Est(French-obso...      None  IN.AR  None
# 3                                               None      None  IN.AS  None
# 4                                               None      None  IN.BR  None
#
#            TYPE_1        ENGTYPE_1 VALIDFR_1 VALIDTO_1 REMARKS_1  Shape_Leng  \
# 0  Union Territor  Union Territory      None      None      None   33.514047
# ...

# %%
india.plot(color='green')
# Out:
# <Axes: >

# %%
india.plot(edgecolor='black', facecolor="skyblue")
# Out:
# <Axes: >

# %%
india.plot(edgecolor='black', facecolor="none")
# Out:
# <Axes: >

# %% [markdown]
# #### Chloropleth Maps

# %% [markdown]
# <i>GeoPanda</i> makes it easy to create Choropleth maps (maps where the color of each shape is based on the value of an associated variable)

# %%
india.plot(column="Shape_Area")
# Out:
# <Axes: >

# %% [markdown]
# #### Creating a legend

# %% [markdown]
# When plotting a map, one can enable a <i>legend</i> using the legend argument

# %%
india.plot(column="Shape_Area", legend=True)
# Out:
# <Axes: >

# %% [markdown]
# #### Changing a legend Orientation

# %%
india.plot(column="Shape_Area", legend=True,
           legend_kwds={"label": "Total Area",
                        "orientation": "horizontal"},
           figsize=(10,15))
# Out:
# <Axes: >

# %% [markdown]
# #### Changing colors

# %% [markdown]
# ~ Colors can be modiefied by plot with the <i>cmap</i> option

# %%
india.plot(column="Shape_Area", cmap="Accent", legend=True)
# Out:
# <Axes: >

# %% [markdown]
# #### Classification Schemes

# %% [markdown]
# The way color maps are scaled can also be manipulated with the scheme option. The scheme option can be set to any scheme provided by mapclassify (e.g. 'box_plot', 'equal_interval', 'fisher_jenks',
# 'fisher_jenks_sampled', 'headtail_breaks', 'jenks_caspall', 'jenks_caspall_forced', 'jenks_caspall_sampled',
# 'max_p_classifier', 'maximum_breaks', 'natural_breaks', 'quantiles', 'percentiles', 'std_mean' or 'user_defined')
#
# A classification scheme is a method for binning continuous data values into 4-7 classes (the default is 5) and map those classes to a color palette.
#
# The commonly used classifications schemes include:
#
# <b>Equal Intervals</b>
#
# Equal-size data ranges (e.g., values within 0-10, 10-20, 20-30, etc.). Pros: Best for data spread across entire
# range of values. Easily understood by map readers. Cons: Avoid if you have highly skewed data or a few big
# outliers.
#
# <b>Quantiles</b>
#
# Equal number of observations in each bin Pros: Looks nice, because it best spreads cclors across full set of data values. Thus, it's often the default scheme for mapping software. Cons: Bins ranges based on the number of observations, not on the dala values. Thus, different classes can have very similar or very different values.
#
# <b>Natural Breaks</b>
#
# Minimizes within-class variance and maximize between-class differences. Typical method is 'fisher-jenks'.
# Pros: Great for exploratory data analysis, because it can identify natural groupings. Cons: Class breaks are best fit to one dataset, so the same bins can't always be used for multiple years.

# %%
india.plot(column="Shape_Area",
           cmap="Accent",
           legend=True,
           scheme="natural_breaks",
           figsize=(10,10))
# Out:
# <Axes: >

# %% [markdown]
# ### Multilayer Maps

# %% [markdown]
# Before combining maps, remember to always ensure they share a common CRS (so they will align)

# %%
vector_file = r"vector_data/map.shp"
city_file = r"vector_data/India Shapefile.zip!India Shape/india_ds.shp"

# %%
india = gpd.read_file(vector_file)
city = gpd.read_file(city_file)

# %%
india.crs

# %%
city.crs

# %%
fig, ax = plt.subplots(figsize=(10,10))
india.plot(ax=ax, color="white", edgecolor="black")
city.plot(ax=ax, color="none", edgecolor="green")
# Out:
# <Axes: >

# %%
plt.close()

# %% [markdown]
# ## Basic Geospatial Analysis

# %% [markdown]
# In **spatial analysis**, our goal is not just to make nice maps, but to actually run analyses that leverage the explicitly spatial nature of our data. The process of doing this is known as **spatial analysis**.
#
# To construct spatial analyses, we string together series of spatial operations in such a way that the end result answers our question of interest. There are many such spatial operations. These are known as **spatial queries**.

# %% [markdown]
# These queries can be divided into:
#
# `Measurement queries`
#
# <li>What is feature A's length?</li>
# <li>What is feature A's area?</li>
# <li>What is feature A's perimeter?</li>
# <li>What is feature A's distance from feature B?</li>
#
# `Relationship queries`
# <li>Is feature A within feature B?</li>
# <li>Does feature A intersect with feature B?</li>
# <li>Does feature A cross feature B?</li>

# %%
vector_file = 'vector_data/map.shp'
india = gpd.read_file(vector_file)
india.head()
india.area
india['New_Area'] = india.area
# Out:
#    ID_0  ISO NAME_0  ID_1               NAME_1  \
# 0   105  IND  India  1287  Andaman and Nicobar
# 1   105  IND  India  1288       Andhra Pradesh
# 2   105  IND  India  1289    Arunachal Pradesh
# 3   105  IND  India  1290                Assam
# 4   105  IND  India  1291                Bihar
#
#                                            VARNAME_1 NL_NAME_1 HASC_1  CC_1  \
# 0  Andaman & Nicobar Islands|Andaman et Nicobar|I...      None  IN.AN  None
# 1                                               None      None  IN.AP  None
# 2  Agence de la Frontisre du Nord-Est(French-obso...      None  IN.AR  None
# 3                                               None      None  IN.AS  None
# 4                                               None      None  IN.BR  None
#
#            TYPE_1        ENGTYPE_1 VALIDFR_1 VALIDTO_1 REMARKS_1  Shape_Leng  \
# 0  Union Territor  Union Territory      None      None      None   33.514047
# ...

# %%
from shapely.geometry import Polygon, LineString, Point
s = gpd.GeoSeries(
    [
        Polygon([(0, 0), (2, 2), (0, 2)]),
        LineString([(0, 0), (2, 2)]),
        LineString([(2, 0), (0, 2)]),
        Point(0, 1),
    ],
)
s
# Out:
# 0    POLYGON ((0.00000 0.00000, 2.00000 2.00000, 0....
# 1        LINESTRING (0.00000 0.00000, 2.00000 2.00000)
# 2        LINESTRING (2.00000 0.00000, 0.00000 2.00000)
# 3                              POINT (0.00000 1.00000)
# dtype: geometry

# %%
s.plot()
# Out:
# <Axes: >

# %%
line = LineString([(-1, 1), (3, 1)])

# %%
s.intersects(line)
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# dtype: bool

# %%
# gpd.read_file(vector_file)

# %%
states_file = r'vector_data/india_states.geojson'
towns_file = r"vector_data/India Shapefile.zip!India Shape/india_ds.shp"

# %%
states = gpd.read_file(states_file)
towns = gpd.read_file(towns_file)

# %%
towns.head()
# Out:
#    DST_ID DISTRICT              STATE  \
# 0       1   Gilgit  JAMMU AND KASHMIR
# 1       2   Kargil  JAMMU AND KASHMIR
# 2       3   Ladakh  JAMMU AND KASHMIR
# 3       4   Chilas  JAMMU AND KASHMIR
# 4       5  Kupwara  JAMMU AND KASHMIR
#
#                                             geometry
# 0  POLYGON ((74.30254 35.65012, 73.84581 35.82461...
# 1  POLYGON ((74.89890 35.62939, 75.04768 35.77413...
# 2  POLYGON ((75.98059 35.93823, 76.16165 35.91142...
# 3  POLYGON ((73.27244 35.81596, 73.32610 35.79237...
# 4  POLYGON ((74.30254 35.65012, 74.54015 35.50695...

# %%
andhra = states[states["NAME_1"]=="Andhra Pradesh"]

# %%
andhra_towns = towns[towns["STATE"]=="ANDHRA PRADESH"]

# %%
fig, ax = plt.subplots(figsize=(10, 10))

andhra.plot(color='lightgrey', ax=ax)
andhra_towns.plot(color='purple', ax=ax, edgecolor="White")
plt.title("Andhra Pradesh")
# Out:
# Text(0.5, 1.0, 'Andhra Pradesh')

# %% [markdown]
# # Convex Hull

# %% [markdown]
# ~ Returns a representation of the smallest convex Polygon containing all the points in the object unless the number of points in the object is less than three

# %%
ch = india.convex_hull

# %%
ch.plot()
# Out:
# <Axes: >

# %% [markdown]
# # Envelope

# %% [markdown]
# ~ Returns a representation of the point or smallest rectangular polygon that contains the object.

# %%
env = india.envelope

# %%
env.plot()
# Out:
# <Axes: >

# %% [markdown]
# # Simplify

# %% [markdown]
# ~ Returns a simplified representation of the geometric object.All points in the simplified object will be within the tolerance distance of the original geometry.

# %%
sim = india.simplify(0.05,preserve_topology=False)

# %%
sim.plot()
# Out:
# <Axes: >

# %% [markdown]
# # END
